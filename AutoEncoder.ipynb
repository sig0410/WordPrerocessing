# %% [markdown]
# ### AutoEncoder
# 1. Encoder와 Decoder를 통해 압축과 해제를 실행
#     - Encoder : 입력(x)의 정보를 최대한 보존하도록 손실 압축 수행
#     - Decoder : 중간 결과물(z)의 정보를 입력(x)과 같아지도록 압축 해제(복원)를 수행
# 2. 복원을 성공적으로 하기 위해, 오토인코더는 특징을 추출하는 방법을 자동으로 학습 <- 이게 핵심
# 3. 휠씬 작은 차원으로 압축하는 병목구간을 지나면서 자동으로 특징을 추출하는 방법을 학습
# ![image.png](attachment:image.png)
